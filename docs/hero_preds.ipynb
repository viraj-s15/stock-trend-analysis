# %% [markdown]
# ### This is for the reliance_data_set_large.csv

# %%
import os
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# Chart drawing
import plotly as py
import plotly.io as pio    
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Show charts when running kernel
init_notebook_mode(connected=True)

layout=go.Layout(paper_bgcolor='rgba(0,0,0,0)', plot_bgcolor='rgba(250,250,250,0.8)')
fig = go.Figure(layout=layout)
templated_fig = pio.to_templated(fig)
pio.templates['my_template'] = templated_fig.layout.template
pio.templates.default = 'my_template'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("../data/hero/hero.csv")
# Need to reverse the db
# df = df.loc[::-1]
df['Date'] = pd.to_datetime(df['Date'])
df = df[(df['Date'].dt.year >= 2010)].copy()
df.index = range(len(df))
# df['Close'] = (df['High'] + df['Low'] )/ 2
df.rename(columns={"Open Price":"Open","High Price":"High","Low Price":"Low","Close Price":"Close","Total Traded Quantity":"Volume","No.of Shares":"Volume"},inplace=True)
# cols = ["Symbol","Ser verbose=Falseies","Prev Close","Last Price","Average Price","Turnover","No. of Trades", "Deliverable Qty",'% Dly Qt to Traded Qty']
# cols = ["WAP","No. of Trades"	,"Total Turnover (Rs.)"	,"Deliverable Quantity"	,"% Deli. Qty to Traded Qty"	,"Spread High-Low"	,"Spread Close-Open"]
cols = "Adj Close"
df.drop(columns=cols,inplace=True)   
df.dropna(inplace=True)
df.head()
# Out:
#         Date         Open         High          Low        Close   Volume
# 0 2021-01-18  3200.000000  3217.550049  3082.250000  3163.149902  1280163
# 1 2021-01-19  3170.500000  3240.750000  3170.500000  3232.899902   770832
# 2 2021-01-20  3239.000000  3292.500000  3230.300049  3275.600098   841752
# 3 2021-01-21  3275.600098  3346.000000  3219.699951  3247.300049  1300181
# 4 2021-01-22  3265.000000  3483.949951  3258.899902  3374.899902  3813020

# %%
fig = make_subplots(rows=2, cols=1)
27,2119.949951,2119.949951,2086.199951,2105.500000,2020.358887,2349001

fig.add_trace(go.Ohlc(x=df.Date,
                      open=df.Open,
                      high=df.High,
                      low=df.Low,
                      close=df.Close,
                      name='Price'), row=1, col=1)

fig.add_trace(go.Scatter(x=df.Date, y=df.Volume, name='Volume'), row=2, col=1)

fig.update(layout_xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <div>                            <div id="dfe1275b-311c-4374-8770-c6c4c0a6f940" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfe1275b-311c-4374-8770-c6c4c0a6f940")) {                    Plotly.newPlot(                        "dfe1275b-311c-4374-8770-c6c4c0a6f940",                        [{"close":[3163.149902,3232.899902,3275.600098,3247.300049,3374.899902,3474.949951,3358.550049,3397.399902,3256.050049,3340.649902,3293.850098,3380.800049,3440.699951,3429.199951,3495.0,3499.449951,3538.949951,3541.5,3515.75,3465.399902,3461.550049,3584.0,3522.850098,3389.699951,3414.149902,3405.449951,3441.600098,3434.399902,3224.0,3350.199951,3476.399902,3424.350098,3419.850098,3461.699951,3463.949951,3448.850098,3419.350098,3350.550049,3264.149902,3255.050049,3190.550049,3107.199951,3119.149902,3095.850098,3067.449951,3033.850098,2941.649902,2937.800049,2963.850098,2913.600098,2956.100098,2886.899902,2887.949951,2941.600098,2928.0,2912.899902,2786.100098,2865.350098,2862.550049,2894.850098,2785.550049,2823.699951,2851.149902,2864.050049,2864.550049,2905.5,2926.25,2860.100098,2819.149902,2793.25,2776.75,2788.199951,2913.300049,2860.800049,2836.300049,2838.350098,2840.149902,2812.350098,2854.75,2906.949951,2915.0,2865.100098,2884.399902,2900.449951,2929.699951,2964.699951,2991.300049,2991.550049,3007.5,2976.75,2972.600098,3008.350098,3048.399902,3052.25,3055.949951,3023.5,3009.0,3004.350098,2985.649902,3007.050049,2975.399902,2914.100098,2891.350098
021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-06T00:0 ...

# %%
def relative_strength_idx(df, n=14):
    close = df['Close']
    delta = close.diff()
    delta = delta[1:]
    pricesUp = delta.copy()
    pricesDown = delta.copy()
    pricesUp[pricesUp < 0] = 0
    pricesDown[pricesDown > 0] = 0    
    rollUp = pricesUp.rolling(n).mean()
    rollDown = pricesDown.abs().rolling(n).mean()
    rs = rollUp / rollDown
    rsi = 100.0 - (100.0 / (1.0 + rs))
    return rsi

df['RSI'] = relative_strength_idx(df).fillna(0)

fig = go.Figure(go.Scatter(x=df.Date, y=df.RSI, name='RSI'))
fig.show()
# Out:
# <div>                            <div id="20facfc8-438b-46d0-9c25-dc61796c82e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20facfc8-438b-46d0-9c25-dc61796c82e9")) {                    Plotly.newPlot(                        "20facfc8-438b-46d0-9c25-dc61796c82e9",                        [{"name":"RSI","x":["2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-06T00:00: ...

# %%
EMA_12 = pd.Series(df['Close'].ewm(span=12, min_periods=12).mean())
EMA_26 = pd.Series(df['Close'].ewm(span=26, min_periods=26).mean())
df['MACD'] = pd.Series(EMA_12 - EMA_26)
df['MACD_signal'] = pd.Series(df.MACD.ewm(span=9, min_periods=9).mean())

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_12, name='EMA 12'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_26, name='EMA 26'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD'], name='MACD'), row=2, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD_signal'], name='Signal line'), row=2, col=1)
fig.show()
# Out:
# <div>                            <div id="9da66421-398a-443a-b13b-15e66ab402dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9da66421-398a-443a-b13b-15e66ab402dc")) {                    Plotly.newPlot(                        "9da66421-398a-443a-b13b-15e66ab402dc",                        [{"name":"Close","x":["2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-06T00:0 ...

# %%
df['Close'] = df['Close'].shift(-1)

# %%
df = df.iloc[33:] # Because of moving averag    If the version of a package is being increased, please remember to return the build/number back to 0.
df = df[:-1]      # Because of shifting close price

df.index = range(len(df))

# %%
test_size  = 0.15
valid_size = 0.15
   
test_split_idx  = int(df.shape[0] * (1-test_size))
valid_split_idx = int(df.shape[0] * (1-(valid_size+test_size)))

train_df  = df.loc[:valid_split_idx].copy()
valid_df  = df.loc[valid_split_idx+1:test_split_idx].copy()
test_df   = df.loc[test_split_idx+1:].copy()

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_df.Date, y=train_df.Close, name='Training'))
fig.add_trace(go.Scatter(x=valid_df.Date, y=valid_df.Close, name='Validation'))
fig.add_trace(go.Scatter(x=test_df.Date,  y=test_df.Close,  name='Test'))
fig.show()
# Out:
# <div>                            <div id="e7ae08d3-9409-4bbb-984d-92341059daa5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7ae08d3-9409-4bbb-984d-92341059daa5")) {                    Plotly.newPlot(                        "e7ae08d3-9409-4bbb-984d-92341059daa5",                        [{"name":"Training","x":["2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00:00:00","2021-08-05T00:00:00","2021-08-06T00:00:00","2021-08-09T00:00:00","2021-08-10T00:00:00","2021-08-11T00:00:00","2021-08-12T00:00:00","2021-08-13T00:00:00","2021-08-16T00:00:00","2021-08-17T00:00:00","2021-08-18T00:00:00","2021-08-20T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-06T00:00:00","2021-09-07T00:00:00","2021-09-08T00:00:00","2021-09-09T00:00:00","2021-09-13T00:00:00","2021-09-14T00:00:00","2021-09-15T00:00:00","2021-09-16T00:00:00","2021-09-17T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-04T00:00:00","2021-10-05T00:00:00","2021-10-06T00:00:00","2021-10-07T00:00:00","2021-10-08T00:00:00","2021-10-11T00:00:00","2021-10-12T00:00:00","2021-10-13T00:00:00","2021-10-14T00:00:00","2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-25T0 ...

# %%
drop_cols = ['Date', 'Volume', 'Open', 'Low', 'High']

train_df = train_df.drop(columns=drop_cols)
valid_df = valid_df.drop(columns=drop_cols)
test_df  = test_df.drop(columns=drop_cols)

# %%
y_train = train_df['Close'].copy()
X_train = train_df.drop(columns=['Close'])

y_valid = valid_df['Close'].copy()
X_valid = valid_df.drop(columns=['Close'])

y_test  = test_df['Close'].copy()
X_test  = test_df.drop(columns=['Close'])

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EMA_9        424 non-null    float64
#  1   SMA_5        424 non-null    float64
#  2   SMA_10       424 non-null    float64
#  3   SMA_15       424 non-null    float64
#  4   SMA_30       424 non-null    float64
#  5   RSI          424 non-null    float64
#  6   MACD         424 non-null    float64
#  7   MACD_signal  424 non-null    float64
# dtypes: float64(8)
# memory usage: 26.6 KB

# %%
# %%time

parameters = {
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [8, 10, 12, 15],
    'gamma': [0.001, 0.005, 0.01, 0.02],
    'random_state': [42],
}

eval_set = [(X_train, y_train), (X_valid, y_valid)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror')
clf = GridSearchCV(model, parameters)

clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best validation score = {clf.best_score_}')
# Out:
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:40:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# ...
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:42:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:43:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.

# %%
# %%time

parameters = {
    'n_estimators': 800,
    'learning_rate': 0.01,
    'max_depth': 64,
    'gamma': 0.001,
    'random_state': 42
}

model = xgb.XGBRegressor(**clf.best_params_, objective='reg:squarederror')
# model = xgb.XGBRegressor(**parameters, objective='reg:squarederror')

# %%
model.fit(X_train, y_train, eval_set=eval_set, verbose=False)

# %%
plot_importance(model)

# %%
y_pred = model.predict(X_test)
print(f'y_true = {np.array(y_test)[:5]}')
print(f'y_pred = {y_pred[:5]}')

# %%
predicted_prices = df.loc[test_split_idx+1:].copy()
predicted_prices['Close'] = y_pred

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close,
                         name='Truth',
                         marker_color='LightSkyBlue'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=predicted_prices.Close,
                         name='Prediction',
                         marker_color='MediumPurple'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_test,
                         name='Truth',
                         marker_color='LightSkyBlue',
                         showlegend=False), row=2, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_pred,
                         name='Prediction',
                         marker_color='MediumPurple',
                         showlegend=False), row=2, col=1)

fig.show()
