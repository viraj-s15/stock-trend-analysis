# %% [markdown]
# ### This is for the reliance_data_set_large.csv

# %%
import os
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# Chart drawing
import plotly as py
import plotly.io as pio    
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Show charts when running kernel
init_notebook_mode(connected=True)

layout=go.Layout(paper_bgcolor='rgba(0,0,0,0)', plot_bgcolor='rgba(250,250,250,0.8)')
fig = go.Figure(layout=layout)
templated_fig = pio.to_templated(fig)
pio.templates['my_template'] = templated_fig.layout.template
pio.templates.default = 'my_template'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("../data/itc/itc.csv")
# Need to reverse the db
# df = df.loc[::-1]
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
df = df[(df['Date'].dt.year >= 2010)].copy()
df.index = range(len(df))
df['Close'] = (df['High'] + df['Low'] )/ 2
df.rename(columns={"Open Price":"Open","High Price":"High","Low Price":"Low","Close Price":"Close","Total Traded Quantity":"Volume","No.of Shares":"Volume"},inplace=True)
# cols = ["Symbol","Ser verbose=Falseies","Prev Close","Last Price","Average Price","Turnover","No. of Trades", "Deliverable Qty",'% Dly Qt to Traded Qty']
# cols = ["WAP","No. of Trades"	,"Total Turnover (Rs.)"	,"Deliverable Quantity"	,"% Deli. Qty to Traded Qty"	,"Spread High-Low"	,"Spread Close-Open"]
cols = "Adj Close"
df.drop(columns=cols,inplace=True)   
df.dropna(inplace=True)
df.head()
# Out:
#         Date        Open        High         Low       Close   Volume
# 0 2020-01-03  241.000000  241.000000  238.000000  239.500000  9284478
# 1 2020-01-06  237.500000  238.300003  235.000000  236.650002  7636617
# 2 2020-01-07  236.050003  237.899994  234.600006  236.250000  8416741
# 3 2020-01-08  234.000000  235.800003  233.250000  234.525002  7043211
# 4 2020-01-09  235.600006  236.600006  235.050003  235.825005  9452653

# %%
fig = make_subplots(rows=2, cols=1)
27,2119.949951,2119.949951,2086.199951,2105.500000,2020.358887,2349001

fig.add_trace(go.Ohlc(x=df.Date,
                      open=df.Open,
                      high=df.High,
                      low=df.Low,
                      close=df.Close,
                      name='Price'), row=1, col=1)

fig.add_trace(go.Scatter(x=df.Date, y=df.Volume, name='Volume'), row=2, col=1)

fig.update(layout_xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <div>                            <div id="cf92ab36-7ef5-4f0d-be4a-120a2303cb14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf92ab36-7ef5-4f0d-be4a-120a2303cb14")) {                    Plotly.newPlot(                        "cf92ab36-7ef5-4f0d-be4a-120a2303cb14",                        [{"close":[239.5,236.6500015,236.25,234.5250015,235.8250045,237.7750015,239.375,241.050003,242.050003,242.0,240.75,241.6500015,239.7249985,238.350006,237.824997,238.050003,235.8499985,233.199997,234.399994,235.0,236.2249985,210.949997,213.375,214.5,215.8499985,214.2249985,212.050003,214.375,213.300003,212.324997,209.8499985,206.324997,202.550003,205.5,207.0,204.625,203.449997,199.125,197.524994,195.9749985,198.5499955,195.0,191.050003,188.875,182.300003,176.75,174.550003,159.8499985,149.300003,151.675003,150.925003,151.0,154.1500015,170.800003,155.5999985,155.5499955,145.5,151.324997,160.5,160.4749985,167.7000045,168.6500015,174.875,179.6749955,180.324997,183.125,183.8499985,188.2249985,188.324997,189.1749955,184.7249985,180.175003,179.7750015,181.824997,181.050003,180.800003,179.425003,181.274994,182.6749955,176.199997,174.7249985,165.949997,163.175003,160.625,160.75,161.699997,169.050003,165.0999985,163.324997,165.2249985,168.375,174.0,181.5499955,188.25,191.375,190.399994,190.949997,193.5,202.125,199.2999955,198.25,198.75,200.324997,200.324997,201.9249955,200.7249985,197.425003,191.5250015,190.125,186.4249955,182.8499985,184.0999985,185.7750015,185.324997,186.125,190.4249955,197.574997,201.3499985,199.5999985,196.699997,199.25,204.6500015,207.25,200.449997,197.25,196.0999985,195.574997,195.25,196.925003,196.125,197.25,195.425003,194.199997,193.850006,192.8499985,195.
020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00: ...

# %%
EMA_12 = pd.Series(df['Close'].ewm(span=12, min_periods=12).mean())
EMA_26 = pd.Series(df['Close'].ewm(span=26, min_periods=26).mean())
df['MACD'] = pd.Series(EMA_12 - EMA_26)
df['MACD_signal'] = pd.Series(df.MACD.ewm(span=9, min_periods=9).mean())

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_12, name='EMA 12'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_26, name='EMA 26'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD'], name='MACD'), row=2, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD_signal'], name='Signal line'), row=2, col=1)
fig.show()
# Out:
# <div>                            <div id="18c828d5-21b6-494f-8d63-8485ca30f9f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18c828d5-21b6-494f-8d63-8485ca30f9f3")) {                    Plotly.newPlot(                        "18c828d5-21b6-494f-8d63-8485ca30f9f3",                        [{"name":"Close","x":["2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:0 ...

# %%
df['Close'] = df['Close'].shift(-1)

# %%
df = df.iloc[33:] # Because of moving averag    If the version of a package is being increased, please remember to return the build/number back to 0.
df = df[:-1]      # Because of shifting close price

df.index = range(len(df))

# %%
test_size  = 0.15
valid_size = 0.15
   
test_split_idx  = int(df.shape[0] * (1-test_size))
valid_split_idx = int(df.shape[0] * (1-(valid_size+test_size)))

train_df  = df.loc[:valid_split_idx].copy()
valid_df  = df.loc[valid_split_idx+1:test_split_idx].copy()
test_df   = df.loc[test_split_idx+1:].copy()

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_df.Date, y=train_df.Close, name='Training'))
fig.add_trace(go.Scatter(x=valid_df.Date, y=valid_df.Close, name='Validation'))
fig.add_trace(go.Scatter(x=test_df.Date,  y=test_df.Close,  name='Test'))
fig.show()
# Out:
# <div>                            <div id="64e0a91a-cbba-4ada-ad44-5a27edd9a5c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64e0a91a-cbba-4ada-ad44-5a27edd9a5c1")) {                    Plotly.newPlot(                        "64e0a91a-cbba-4ada-ad44-5a27edd9a5c1",                        [{"name":"Training","x":["2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T0 ...

# %%
drop_cols = ['Date', 'Volume', 'Open', 'Low', 'High']

train_df = train_df.drop(columns=drop_cols)
valid_df = valid_df.drop(columns=drop_cols)
test_df  = test_df.drop(columns=drop_cols)

# %%
y_train = train_df['Close'].copy()
X_train = train_df.drop(columns=['Close'])

y_valid = valid_df['Close'].copy()
X_valid = valid_df.drop(columns=['Close'])

y_test  = test_df['Close'].copy()
X_test  = test_df.drop(columns=['Close'])

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EMA_9        561 non-null    float64
#  1   SMA_5        561 non-null    float64
#  2   SMA_10       561 non-null    float64
#  3   SMA_15       561 non-null    float64
#  4   SMA_30       561 non-null    float64
#  5   RSI          561 non-null    float64
#  6   MACD         561 non-null    float64
#  7   MACD_signal  561 non-null    float64
# dtypes: float64(8)
# memory usage: 35.2 KB

# %%
# %%time

parameters = {
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [8, 10, 12, 15],
    'gamma': [0.001, 0.005, 0.01, 0.02],
    'random_state': [42],
}

eval_set = [(X_train, y_train), (X_valid, y_valid)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror')
clf = GridSearchCV(model, parameters)

clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best validation score = {clf.best_score_}')
# Out:
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:15:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:16:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# ...
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:18:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# Best params: {'gamma': 0.01, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'random_state': 42}
# Best validation score = 0.35233934569756836
# CPU times: user 48min 5s, sys: 54 s, total: 48min 59s
# Wall time: 3min 9s

# %%
# %%time

parameters = {
    'n_estimators': 800,
    'learning_rate': 0.01,
    'max_depth': 64,
    # 'gamma': 0.001,
    'random_state': [42]
}

model = xgb.XGBRegressor(**clf.best_params_, objective='reg:squarederror')
# Out:
# CPU times: user 28 µs, sys: 0 ns, total: 28 µs
# Wall time: 34.6 µs

# %%
model.fit(X_train, y_train, eval_set=eval_set, verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.001, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=64, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=800, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
y_pred = model.predict(X_test)
print(f'y_true = {np.array(y_test)[:5]}')
print(f'y_pred = {y_pred[:5]}')
# Out:
# y_true = [337.199997 338.350006 339.75     340.024994 339.849991]
# y_pred = [263.8367  263.03726 262.8475  262.8475  262.90952]

# %%
predicted_prices = df.loc[test_split_idx+1:].copy()
predicted_prices['Close'] = y_pred

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close,
                         name='Truth',
                         marker_color='LightSkyBlue'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=predicted_prices.Close,
                         name='Prediction',
                         marker_color='MediumPurple'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_test,
                         name='Truth',
                         marker_color='LightSkyBlue',
                         showlegend=False), row=2, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_pred,
                         name='Prediction',
                         marker_color='MediumPurple',
                         showlegend=False), row=2, col=1)

fig.show()
# Out:
# <div>                            <div id="58d71def-8455-4930-a8b0-d2fb249888ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58d71def-8455-4930-a8b0-d2fb249888ff")) {                    Plotly.newPlot(                        "58d71def-8455-4930-a8b0-d2fb249888ff",                        [{"marker":{"color":"LightSkyBlue"},"name":"Truth","x":["2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","202 ...
