# %% [markdown]
# ### This is for the itc data but the data does not seem to be reliable or has a lot of bias

# %%
import os
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# Chart drawing
import plotly as py
import plotly.io as pio    
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Show charts when running kernel
init_notebook_mode(connected=True)

layout=go.Layout(paper_bgcolor='rgba(0,0,0,0)', plot_bgcolor='rgba(250,250,250,0.8)')
fig = go.Figure(layout=layout)
templated_fig = pio.to_templated(fig)
pio.templates['my_template'] = templated_fig.layout.template
pio.templates.default = 'my_template'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("../data/itc/itc.csv")
# Need to reverse the db
# df = df.loc[::-1]
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
df = df[(df['Date'].dt.year >= 2010)].copy()
df.index = range(len(df))
# df['Close'] = (df['High'] + df['Low'] )/ 2
df.rename(columns={"Open Price":"Open","High Price":"High","Low Price":"Low","Close Price":"Close","Total Traded Quantity":"Volume","No.of Shares":"Volume"},inplace=True)
# cols = ["Symbol","Ser verbose=Falseies","Prev Close","Last Price","Average Price","Turnover","No. of Trades", "Deliverable Qty",'% Dly Qt to Traded Qty']
# cols = ["WAP","No. of Trades"	,"Total Turnover (Rs.)"	,"Deliverable Quantity"	,"% Deli. Qty to Traded Qty"	,"Spread High-Low"	,"Spread Close-Open"]
cols = "Adj Close"
df.drop(columns=cols,inplace=True)   
df.dropna(inplace=True)
df.head()
# Out:
#         Date        Open        High         Low       Close   Volume
# 0 2020-01-03  241.000000  241.000000  238.000000  238.500000  9284478
# 1 2020-01-06  237.500000  238.300003  235.000000  235.100006  7636617
# 2 2020-01-07  236.050003  237.899994  234.600006  235.350006  8416741
# 3 2020-01-08  234.000000  235.800003  233.250000  234.199997  7043211
# 4 2020-01-09  235.600006  236.600006  235.050003  235.800003  9452653

# %%
fig = make_subplots(rows=2, cols=1)
27,2119.949951,2119.949951,2086.199951,2105.500000,2020.358887,2349001

fig.add_trace(go.Ohlc(x=df.Date,
                      open=df.Open,
                      high=df.High,
                      low=df.Low,
                      close=df.Close,
                      name='Price'), row=1, col=1)

fig.add_trace(go.Scatter(x=df.Date, y=df.Volume, name='Volume'), row=2, col=1)

fig.update(layout_xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <div>                            <div id="3af0fdbb-51a1-4b07-bbb9-28abdbef4d2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3af0fdbb-51a1-4b07-bbb9-28abdbef4d2e")) {                    Plotly.newPlot(                        "3af0fdbb-51a1-4b07-bbb9-28abdbef4d2e",                        [{"close":[238.5,235.100006,235.350006,234.199997,235.800003,238.0,239.25,243.25,242.399994,240.75,239.949997,241.899994,238.449997,238.050003,237.899994,238.149994,234.600006,230.75,236.649994,234.050003,235.149994,207.600006,215.649994,216.449997,213.550003,213.399994,210.550003,212.600006,213.050003,211.899994,207.699997,204.800003,203.850006,206.699997,207.449997,203.0,201.800003,198.600006,197.550003,197.550003,195.300003,193.850006,187.5,188.050003,181.75,177.199997,175.649994,155.800003,162.25,147.25,149.149994,150.699997,161.850006,175.5,154.300003,149.699997,147.350006,156.399994,163.199997,159.199997,171.699997,166.399994,177.899994,181.550003,178.649994,185.25,181.600006,189.350006,186.350006,188.100006,180.699997,179.600006,182.25,180.550003,180.050003,179.850006,179.449997,182.149994,182.050003,174.050003,173.899994,163.899994,161.0,158.25,158.449997,165.050003,165.399994,163.800003,164.649994,164.75,170.75,175.75,188.949997,186.350006,191.699997,192.149994,190.649994,197.350006,200.550003,197.25,196.699997,200.149994,200.0,197.649994,198.5,199.050003,194.25,193.899994,187.199997,185.0,181.199997,186.600006,184.050003,185.0,185.850006,191.850006,202.100006,195.199997,197.25,194.649994,202.899994,205.850006,207.550003,199.800003,194.25,196.300003,195.449997,194.350006,197.550003,195.899994,198.699997,193.850006,194.050003,192.699997,192.25,196.550003,200.
'].ewm(span=12, min_periods=12).mean())
EMA_26 = pd.Series(df['Close'].ewm(span=26, min_periods=26).mean())
df['MACD'] = pd.Series(EMA_12 - EMA_26)
df['MACD_signal'] = pd.Series(df.MACD.ewm(span=9, min_periods=9).mean())

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_12, name='EMA 12'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_26, name='EMA 26'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD'], name='MACD'), row=2, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD_signal'], name='Signal line'), row=2, col=1)
fig.show()
# Out:
# <div>                            <div id="8fc1597f-02e1-4394-b791-09d79d43163c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fc1597f-02e1-4394-b791-09d79d43163c")) {                    Plotly.newPlot(                        "8fc1597f-02e1-4394-b791-09d79d43163c",                        [{"name":"Close","x":["2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:0 ...

# %%
df['Close'] = df['Close'].shift(-1)

# %%
df = df.iloc[33:] # Because of moving averag    If the version of a package is being increased, please remember to return the build/number back to 0.
df = df[:-1]      # Because of shifting close price

df.index = range(len(df))

# %%
test_size  = 0.15
valid_size = 0.15
   
test_split_idx  = int(df.shape[0] * (1-test_size))
valid_split_idx = int(df.shape[0] * (1-(valid_size+test_size)))

train_df  = df.loc[:valid_split_idx].copy()
valid_df  = df.loc[valid_split_idx+1:test_split_idx].copy()
test_df   = df.loc[test_split_idx+1:].copy()

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_df.Date, y=train_df.Close, name='Training'))
fig.add_trace(go.Scatter(x=valid_df.Date, y=valid_df.Close, name='Validation'))
fig.add_trace(go.Scatter(x=test_df.Date,  y=test_df.Close,  name='Test'))
fig.show()
# Out:
# <div>                            <div id="9e242557-070e-4cb3-9fb6-28609adba47f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e242557-070e-4cb3-9fb6-28609adba47f")) {                    Plotly.newPlot(                        "9e242557-070e-4cb3-9fb6-28609adba47f",                        [{"name":"Training","x":["2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T0 ...

# %%
drop_cols = ['Date', 'Volume', 'Open', 'Low', 'High']

train_df = train_df.drop(columns=drop_cols)
valid_df = valid_df.drop(columns=drop_cols)
test_df  = test_df.drop(columns=drop_cols)

# %%
y_train = train_df['Close'].copy()
X_train = train_df.drop(columns=['Close'])

y_valid = valid_df['Close'].copy()
X_valid = valid_df.drop(columns=['Close'])

y_test  = test_df['Close'].copy()
X_test  = test_df.drop(columns=['Close'])

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EMA_9        561 non-null    float64
#  1   SMA_5        561 non-null    float64
#  2   SMA_10       561 non-null    float64
#  3   SMA_15       561 non-null    float64
#  4   SMA_30       561 non-null    float64
#  5   RSI          561 non-null    float64
#  6   MACD         561 non-null    float64
#  7   MACD_signal  561 non-null    float64
# dtypes: float64(8)
# memory usage: 35.2 KB

# %%
# %%time

parameters = {
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [8, 10, 12, 15],
    'gamma': [0.001, 0.005, 0.01, 0.02],
    'random_state': [42],
}

eval_set = [(X_train, y_train), (X_valid, y_valid)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror')
clf = GridSearchCV(model, parameters)

clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best validation score = {clf.best_score_}')
# Out:
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:20:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:21:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:22:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# ...
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:23:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# Best params: {'gamma': 0.005, 'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100, 'random_state': 42}
# Best validation score = 0.35979126528673644
# CPU times: user 46min 18s, sys: 52.3 s, total: 47min 10s
# Wall time: 3min 1s

# %%
# %%time

parameters = {
    'n_estimators': 800,
    'learning_rate': 0.01,
    'max_depth': 64,
    'gamma': 0.001,
    'random_state': 42
}

# model = xgb.XGBRegressor(**clf.best_params_, objective='reg:squarederror')
model = xgb.XGBRegressor(**parameters, objective='reg:squarederror')
# Out:
# CPU times: user 31 µs, sys: 0 ns, total: 31 µs
# Wall time: 37.2 µs

# %%
model.fit(X_train, y_train, eval_set=eval_set, verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.001, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=64, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=800, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
y_pred = model.predict(X_test)
print(f'y_true = {np.array(y_test)[:5]}')
print(f'y_pred = {y_pred[:5]}')
# Out:
# y_true = [337.200012 340.25     339.799988 340.75     340.299988]
# y_pred = [260.9537  261.13626 261.76785 262.3696  262.45987]

# %%
predicted_prices = df.loc[test_split_idx+1:].copy()
predicted_prices['Close'] = y_pred

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close,
                         name='Truth',
                         marker_color='LightSkyBlue'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=predicted_prices.Close,
                         name='Prediction',
                         marker_color='MediumPurple'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_test,
                         name='Truth',
                         marker_color='LightSkyBlue',
                         showlegend=False), row=2, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_pred,
                         name='Prediction',
                         marker_color='MediumPurple',
                         showlegend=False), row=2, col=1)

fig.show()
# Out:
# <div>                            <div id="3ddbb0fd-e18d-4523-bfb8-3a40fab35eb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ddbb0fd-e18d-4523-bfb8-3a40fab35eb7")) {                    Plotly.newPlot(                        "3ddbb0fd-e18d-4523-bfb8-3a40fab35eb7",                        [{"marker":{"color":"LightSkyBlue"},"name":"Truth","x":["2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","202 ...
