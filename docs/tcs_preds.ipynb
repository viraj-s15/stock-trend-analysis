# %% [markdown]
# ### This is for the reliance_data_set_large.csv

# %%
import os
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# Chart drawing
import plotly as py
import plotly.io as pio    
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Show charts when running kernel
init_notebook_mode(connected=True)

layout=go.Layout(paper_bgcolor='rgba(0,0,0,0)', plot_bgcolor='rgba(250,250,250,0.8)')
fig = go.Figure(layout=layout)
templated_fig = pio.to_templated(fig)
pio.templates['my_template'] = templated_fig.layout.template
pio.templates.default = 'my_template'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("../data/tcs/tcs.csv")

df['Date'] = pd.to_datetime(df['Date'])
df = df[(df['Date'].dt.year >= 2010)].copy()
df.index = range(len(df))
df.rename(columns={"Open Price":"Open","High Price":"High","Low Price":"Low","Close Price":"Close","Total Traded Quantity":"Volume"},inplace=True)
# cols = ["Symbol","Ser verbose=Falseies","Prev Close","Last Price","Average Price","Turnover","No. of Trades", "Deliverable Qty",'% Dly Qt to Traded Qty']
cols = "Adj Close"
df.drop(columns=cols,inplace=True)   
df.dropna(inplace=True)
df.head()
# Out:
#         Date         Open         High          Low        Close   Volume
# 0 2020-02-28  2068.000000  2069.500000  1990.000000  2000.150024  4298076
# 1 2020-03-02  2035.000000  2053.949951  1985.699951  2001.300049  2667076
# 2 2020-03-03  2020.000000  2060.000000  2012.000000  2036.199951  2757585
# 3 2020-03-04  2056.000000  2094.449951  2025.000000  2083.199951  3237002
# 4 2020-03-05  2085.699951  2147.750000  2084.050049  2125.050049  3937056

# %%
fig = make_subplots(rows=2, cols=1)
27,2119.949951,2119.949951,2086.199951,2105.500000,2020.358887,2349001

fig.add_trace(go.Ohlc(x=df.Date,
                      open=df.Open,
                      high=df.High,
                      low=df.Low,
                      close=df.Close,
                      name='Price'), row=1, col=1)

fig.add_trace(go.Scatter(x=df.Date, y=df.Volume, name='Volume'), row=2, col=1)

fig.update(layout_xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <div>                            <div id="f2af63e2-24e4-443a-bad0-9dd1f22cf34e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2af63e2-24e4-443a-bad0-9dd1f22cf34e")) {                    Plotly.newPlot(                        "f2af63e2-24e4-443a-bad0-9dd1f22cf34e",                        [{"close":[2000.150024,2001.300049,2036.199951,2083.199951,2125.050049,2116.449951,1972.349976,1953.699951,1769.849976,1806.300049,1696.400024,1658.0,1654.400024,1636.349976,1797.449951,1669.699951,1703.150024,1750.300049,1790.949951,1824.5,1778.5,1826.099976,1708.75,1654.199951,1775.199951,1705.449951,1766.150024,1759.25,1735.150024,1716.050049,1806.199951,1818.650024,1737.650024,1769.5,1878.25,1818.550049,1836.599976,1859.050049,1905.650024,2014.449951,1930.449951,1932.75,1903.599976,1891.650024,1893.400024,1935.300049,1949.5,1949.650024,1902.349976,1892.900024,1945.599976,1948.650024,1953.599976,1991.199951,2020.349976,1943.0,2005.300049,2004.300049,1972.349976,2045.25,2047.150024,2046.150024,2091.550049,2048.25,2071.75,2072.050049,2108.75,2067.649902,2039.5,2029.900024,2045.800049,2047.800049,2038.099976,2044.599976,2027.949951,2035.300049,2042.199951,2016.099976,2118.850098,2101.649902,2082.149902,2092.050049,2157.149902,2199.649902,2263.199951,2269.899902,2218.899902,2204.350098,2222.350098,2220.0,2171.949951,2233.899902,2234.75,2200.75,2207.899902,2225.050049,2190.949951,2171.199951,2157.399902,2206.800049,2309.75,2276.050049,2279.5,2281.399902,2254.149902,2249.699951,2259.5,2308.100098,2295.350098,2282.800049,2279.899902,2257.350098,2254.449951,2242.149902,2253.399902,2269.75,2256.600098,2252.850098,2248.600098,2248.100098,2242.649902,2253.5,2248.399902,2238.550049,2257.25,2246.350098,2265.149902,2299.5,2288.800049,2327.050049,2348.199951,2327.649902,2331.149902,2374.100098,2491.399902,2491.399902,2503.0,2460.949951,2449.899902,2465.300049,2522.949951,2467.449951,2332.25,2422.300049,2426.300049,2488.399902,2492.300049,2523.449951,2705.800049,2714.300049,2735.949951,2825.699951,2812.949951,2830.0,2826.550049,2809.600098,2740.600098,2763.300049,2711.550049,2739.0,2675.399902,2671.149902,2686.800049,2688.199951,2630.149902,2622.199951,2632.649902,2664.850098,2604.600098,2633.600098,2653.149902,2685.699951,2707.449951,2726.600098,2649.600098,2687.800049,2671.050049,2656.850098,2670.350098,2666.050049,2626.649902,2636.899902,2660.25,2724.25,2722.050049,2701.300049,2720.600098,2679.649902,2726.800049,2749.550049,2709.449951,2727.550049,2737.699951,2797.300049,2810.800049,2784.300049,2783.600098,2797.699951,2761.550049,2814.199951,2838.199951,2861.0,2820.149902,2872.5,2908.75,2909.350098,2929.399902,2930.5,2909.300049,2862.75,2928.25,3039.449951,3093.0,3051.5,3032.800049,3120.899902,3176.449951,3174.850098,3158.949951,3250.699951,3233.350098,3221.75,3260.699951,3308.800049,3273.850098,3303.100098,3291.300049,3261.050049,3196.550049,3111.350098,3139.350098,3203.449951,3200.050049,3188.449951,3157.949951,3214.100098,3176.899902,3213.300049,3206.0,3190.800049,3139.850098,3108.800049,3073.100098,3057.350098,3071.850098,2958.449951,2980.199951,2948.100098,2995.300049,2894.300049,2924.199951,3006.350098,3059.100098,3049.699951,3008.050049,3006.949951,3050.949951,3070.949951,3057.949951,3066.149902,3110.050049,3112.949951,3036.5,3050.199951,3129.649902,3142.600098,3121.100098,3064.850098,3066.800049,3158.550049,3177.850098,3165.0,3238.899902,3264.699951,3271.399902,3317.350098,3322.25,3246.550049,3104.050049,3218.949951,3195.149902,3161.800049,3144.550049,3118.800049,3109.5,3100.800049,3132.0,3124.100098,3115.25,3035.649902,3037.0,3049.75,3095.699951,3111.449951,3132.899902,3145.5,3122.600098,3087.600098,3051.5,3069.75,3088.800049,3082.0,3060.0,3080.5,3081.5,3114.0,3158.5,3180.0,3143.600098,3159.149902,3153.0,312 ...

# %%
df['EMA_9'] = df['Close'].ewm(9).mean().shift()
df['SMA_5'] = df['Close'].rolling(5).mean().shift()
df['SMA_10'] = df['Close'].rolling(10).mean().shift()
df['SMA_15'] = df['Close'].rolling(15).mean().shift()
df['SMA_30'] = df['Close'].rolling(30).mean().shift()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df.Date, y=df.EMA_9, name='EMA 9'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_5, name='SMA 5'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_10, name='SMA 10'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_15, name='SMA 15'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_30, name='SMA 30'))
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close', opacity=0.2))
fig.show()
# Out:
# <div>                            <div id="7886096d-d1aa-451d-a55c-e05ac243f117" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7886096d-d1aa-451d-a55c-e05ac243f117")) {                    Plotly.newPlot(                        "7886096d-d1aa-451d-a55c-e05ac243f117",                        [{"name":"EMA 9","x":["2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:0 ...

# %%
def relative_strength_idx(df, n=14):
    close = df['Close']
    delta = close.diff()
    delta = delta[1:]
    pricesUp = delta.copy()
    pricesDown = delta.copy()
    pricesUp[pricesUp < 0] = 0
    pricesDown[pricesDown > 0] = 0    
    rollUp = pricesUp.rolling(n).mean()
    rollDown = pricesDown.abs().rolling(n).mean()
    rs = rollUp / rollDown
    rsi = 100.0 - (100.0 / (1.0 + rs))
    return rsi

df['RSI'] = relative_strength_idx(df).fillna(0)

fig = go.Figure(go.Scatter(x=df.Date, y=df.RSI, name='RSI'))
fig.show()
# Out:
# <div>                            <div id="5ed702c3-6fa5-48dc-a138-3ba5375362ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ed702c3-6fa5-48dc-a138-3ba5375362ef")) {                    Plotly.newPlot(                        "5ed702c3-6fa5-48dc-a138-3ba5375362ef",                        [{"name":"RSI","x":["2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00: ...

# %%
EMA_12 = pd.Series(df['Close'].ewm(span=12, min_periods=12).mean())
EMA_26 = pd.Series(df['Close'].ewm(span=26, min_periods=26).mean())
df['MACD'] = pd.Series(EMA_12 - EMA_26)
df['MACD_signal'] = pd.Series(df.MACD.ewm(span=9, min_periods=9).mean())

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_12, name='EMA 12'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_26, name='EMA 26'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD'], name='MACD'), row=2, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD_signal'], name='Signal line'), row=2, col=1)
fig.show()
# Out:
# <div>                            <div id="a98b4d74-f62d-41a8-9bb7-f487e31a8a24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a98b4d74-f62d-41a8-9bb7-f487e31a8a24")) {                    Plotly.newPlot(                        "a98b4d74-f62d-41a8-9bb7-f487e31a8a24",                        [{"name":"Close","x":["2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:0 ...

# %%
df['Close'] = df['Close'].shift(-1)

# %%
df = df.iloc[33:] # Because of moving averag    If the version of a package is being increased, please remember to return the build/number back to 0.
df = df[:-1]      # Because of shifting close price

df.index = range(len(df))

# %%
test_size  = 0.15
valid_size = 0.15
   
test_split_idx  = int(df.shape[0] * (1-test_size))
valid_split_idx = int(df.shape[0] * (1-(valid_size+test_size)))

train_df  = df.loc[:valid_split_idx].copy()
valid_df  = df.loc[valid_split_idx+1:test_split_idx].copy()
test_df   = df.loc[test_split_idx+1:].copy()

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_df.Date, y=train_df.Close, name='Training'))
fig.add_trace(go.Scatter(x=valid_df.Date, y=valid_df.Close, name='Validation'))
fig.add_trace(go.Scatter(x=test_df.Date,  y=test_df.Close,  name='Test'))
fig.show()
# Out:
# <div>                            <div id="2ace2a81-dcb8-49b2-a62f-ea4fc1efa303" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ace2a81-dcb8-49b2-a62f-ea4fc1efa303")) {                    Plotly.newPlot(                        "2ace2a81-dcb8-49b2-a62f-ea4fc1efa303",                        [{"name":"Training","x":["2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-19T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","2020-10-22T00:00:00","2020-10-23T00:00:00","2020-10-26T00:00:00","2020-10-27T00:00:00","2020-10-28T00:00:00","2020-10-29T00:00:00","2020-10-30T00:00:00","2020-11-02T00:00:00","2020-11-03T00:00:00","2020-11-04T00:00:00","2020-11-05T00:00:00","2020-11-06T00:00:00","2020-11-09T00:00:00","2020-11-10T00:00:00","2020-11-11T00:00:00","2020-11-12T00:00:00","2020-11-13T00:00:00","2020-11-14T00:00:00","2020-11-17T00:00:00","2020-11-18T00:00:00","2020-11-19T00:00:00","2020-11-20T00:00:00","2020-11-23T00:00:00","2020-11-24T00:00:00","2020-11-25T00:00:00","2020-11-26T00:00:00","2020-11-27T00:00:00","2020-12-01T00:00:00","2020-12-02T0 ...

# %%
drop_cols = ['Date', 'Volume', 'Open', 'Low', 'High']

train_df = train_df.drop(columns=drop_cols)
valid_df = valid_df.drop(columns=drop_cols)
test_df  = test_df.drop(columns=drop_cols)

# %%
y_train = train_df['Close'].copy()
X_train = train_df.drop(columns=['Close'])

y_valid = valid_df['Close'].copy()
X_valid = valid_df.drop(columns=['Close'])

y_test  = test_df['Close'].copy()
X_test  = test_df.drop(columns=['Close'])

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EMA_9        438 non-null    float64
#  1   SMA_5        438 non-null    float64
#  2   SMA_10       438 non-null    float64
#  3   SMA_15       438 non-null    float64
#  4   SMA_30       438 non-null    float64
#  5   RSI          438 non-null    float64
#  6   MACD         438 non-null    float64
#  7   MACD_signal  438 non-null    float64
# dtypes: float64(8)
# memory usage: 27.5 KB

# %%
# %%time

parameters = {
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [8, 10, 12, 15],
    'gamma': [0.001, 0.005, 0.01, 0.02],
    'random_state': [42]
}

eval_set = [(X_train, y_train), (X_valid, y_valid)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror')
clf = GridSearchCV(model, parameters)

clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best validation score = {clf.best_score_}')
# Out:
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:11:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# ...
#
# [15:12:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [15:12:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# Best params: {'gamma': 0.001, 'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100, 'random_state': 42}
# Best validation score = -0.1062945226173202
# CPU times: user 43min 1s, sys: 49.7 s, total: 43min 51s
# Wall time: 2min 49s

# %%
# %%time

parameters = {
    'n_estimators': 800,
    'learning_rate': 0.01,
    'max_depth': 64,
    # 'gamma': 0.001,
    'random_state': [42]
}

model = xgb.XGBRegressor(**clf.best_params_, objective='reg:squarederror')
# Out:
# CPU times: user 19 µs, sys: 0 ns, total: 19 µs
# Wall time: 23.6 µs

# %%
model.fit(X_train, y_train, eval_set=eval_set, verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.001, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
y_pred = model.predict(X_test)
print(f'y_true = {np.array(y_test)[:5]}')
print(f'y_pred = {y_pred[:5]}')
# Out:
# y_true = [3359.899902 3219.600098 3210.550049 3206.300049 3142.      ]
# y_pred = [3511.6768 3501.0508 3462.5168 3336.526  3286.8887]

# %%
predicted_prices = df.loc[test_split_idx+1:].copy()
predicted_prices['Close'] = y_pred

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close,
                         name='Truth',
                         marker_color='LightSkyBlue'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=predicted_prices.Close,
                         name='Prediction',
                         marker_color='MediumPurple'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_test,
                         name='Truth',
                         marker_color='LightSkyBlue',
                         showlegend=False), row=2, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_pred,
                         name='Prediction',
                         marker_color='MediumPurple',
                         showlegend=False), row=2, col=1)

fig.show()
# Out:
# <div>                            <div id="133a91f1-4d55-403a-9f5c-84a160888eff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("133a91f1-4d55-403a-9f5c-84a160888eff")) {                    Plotly.newPlot(                        "133a91f1-4d55-403a-9f5c-84a160888eff",                        [{"marker":{"color":"LightSkyBlue"},"name":"Truth","x":["2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-19T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","2020-10-22T00:00:00","2020-10-23T00:00:00","2020-10-26T00:00:00","2020-10-27T00:00:00","2020-10-28T00:00:00","2020-10-29T00:00:00","2020-10-30T00:00:00","2020-11-02T00:00:00","2020-11-03T00:00:00","2020-11-04T00:00:00","2020-11-05T00:00:00","2020-11-06T00:00:00","2020-11-09T00:00:00","2020-11-10T00:00:00","2020-11-11T00:00:00","2020-11-12T00:00:00","2020-11-13T00:00:00","2020-11-14T00:00:00","2020-11-17T00:00:00","2020-11-18T00:00:00","2020-11-19T00:00:00","2020-11-20T00:00:00","2020-11-23T00:00:00","2020-11-24T00:00:00","2020-11-25T00:00:00","2020-11-26T00:00:00","2020-11-27T00:00:00","202 ...

# %% [markdown]
# <!-- 1st MAy 2020 - 31st december 2022 -->
