# %% [markdown]
# ### This is for the reliance_data_set_large.csv

# %%
import os
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# Chart drawing
import plotly as py
import plotly.io as pio    
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Show charts when running kernel
init_notebook_mode(connected=True)

layout=go.Layout(paper_bgcolor='rgba(0,0,0,0)', plot_bgcolor='rgba(250,250,250,0.8)')
fig = go.Figure(layout=layout)
templated_fig = pio.to_templated(fig)
pio.templates['my_template'] = templated_fig.layout.template
pio.templates.default = 'my_template'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("../data/reliance/reliance.csv")
# Need to reverse the db
# df = df.loc[::-1]
df['Date'] = pd.to_datetime(df['Date'])
df = df[(df['Date'].dt.year >= 2010)].copy()
df.index = range(len(df))
# df['Close'] = (df['High'] + df['Low'] )/ 2
df.rename(columns={"Open Price":"Open","High Price":"High","Low Price":"Low","Close Price":"Close","Total Traded Quantity":"Volume","No.of Shares":"Volume"},inplace=True)
# cols = ["Symbol","Ser verbose=Falseies","Prev Close","Last Price","Average Price","Turnover","No. of Trades", "Deliverable Qty",'% Dly Qt to Traded Qty']
# cols = ["WAP","No. of Trades"	,"Total Turnover (Rs.)"	,"Deliverable Quantity"	,"% Deli. Qty to Traded Qty"	,"Spread High-Low"	,"Spread Close-Open"]
cols = "Adj Close"
df.drop(columns=cols,inplace=True)   
df.dropna(inplace=True)
df.head()
# Out:
#         Date       Open       High        Low      Close    Volume
# 0 2020-01-17  25.600000  25.799999  25.150000  25.299999  171365.0
# 1 2020-01-20  25.450001  25.700001  25.000000  25.049999  212398.0
# 2 2020-01-21  25.000000  25.250000  24.400000  24.600000  257001.0
# 3 2020-01-22  24.650000  25.100000  24.500000  24.850000  156254.0
# 4 2020-01-23  25.000000  26.799999  24.700001  26.600000  784951.0

# %%
fig = make_subplots(rows=2, cols=1)
27,2119.949951,2119.949951,2086.199951,2105.500000,2020.358887,2349001

fig.add_trace(go.Ohlc(x=df.Date,
                      open=df.Open,
                      high=df.High,
                      low=df.Low,
                      close=df.Close,
                      name='Price'), row=1, col=1)

fig.add_trace(go.Scatter(x=df.Date, y=df.Volume, name='Volume'), row=2, col=1)

fig.update(layout_xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <div>                            <div id="4a8708ac-8991-41d5-9c65-04271f3f2408" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a8708ac-8991-41d5-9c65-04271f3f2408")) {                    Plotly.newPlot(                        "4a8708ac-8991-41d5-9c65-04271f3f2408",                        [{"close":[25.299999,25.049999,24.6,24.85,26.6,26.35,26.200001,27.15,28.9,27.549999,27.4,24.0,24.6,25.299999,25.200001,25.049999,24.75,24.700001,23.75,23.15,22.950001,22.4,22.5,23.35,23.6,22.950001,22.549999,22.4,22.0,21.1,20.25,20.1,19.9,20.0,18.950001,18.0,17.9,16.0,17.0,16.25,16.0,14.45,13.95,13.9,11.15,11.0,11.6,12.75,12.8,12.6,12.9,13.96,15.35,16.879999,17.719999,18.6,17.67,16.84,17.68,18.5,18.450001,17.690001,17.5,17.66,17.290001,17.049999,17.200001,17.18,17.1,17.049999,16.65,16.5,16.549999,16.35,17.15,18.0,18.9,18.0,17.6,17.0,16.5,17.299999,17.65,17.15,16.950001,16.85,16.950001,17.0,17.5,17.5,17.549999,17.5,19.049999,19.85,19.1,18.700001,18.6,18.35,18.35,18.200001,18.049999,18.6,19.1,20.25,19.85,19.700001,19.450001,19.049999,18.85,18.9,20.25,20.299999,20.15,20.0,20.0,19.65,19.799999,19.15,19.049999,18.65,19.75,20.0,19.799999,19.65,19.1,19.299999,19.200001,19.049999,19.049999,19.5,19.200001,19.1,19.1,19.200001,19.15,19.15,19.1,19.35,19.85,19.950001,22.15,23.1,22.75,22.9,23.1,22.75,22.5,22.299999,21.950001,21.85,22.0,21.549999,21.15,21.200001,21.25,20.950001,21.65,21.0,20.549999,20.9,21.35,21.450001,21.35,21.1,20.9,21.35,20.4,19.200001,19.299999,18.85,19.299999,19.65,19.5,19.450001,19.35,19.299999,19.35,19.0,18.950001,18.700001,18.85,18.6,18.799999,18.5,18.549999,18.65,19.15,18.799999,18.700001,18.799999,18.6,18.549999,18.299999,18.299999,18.200001,18.1,18.200001,18.1,18.450001,18.450001,18.450001,18.950001,18.799999,18.75,18.65,18.799999,18.85,19.0,19.299999,19.200001,20.65,20.85,20.6,20.85,21.85,22.950001,23.049999,23.75,24.049999,24.65,23.35,22.799999,21.85,23.4,23.25,23.1,23.85,23.9,23.700001,21.549999,22.200001,22.799999,22.85,23.200001,22.9,22.85,24.0,23.9,24.049999,27.450001,28.1,29.0,33.349998,34.849998,32.849998,33.0,31.25,31.549999,31.299999,31.200001,30.9,30.049999,29.0,28.75,27.450001,30.15,31.35,30.299999,29.65,29.5,31.1,30.85,31.65,31.0,30.6,31.85,32.5,31.049999,30.799999,30.700001,30.65,30.6,29.85,29.700001,30.200001,32.700001,31.799999,32.450001,32.599998,32.0,32.299999,31.549999,31.799999,31.0,31.700001,31.299999,30.75,30.65,30.65,29.65,29.200001,30.299999,30.4,27.700001,27.75,29.200001,29.6,29.1,29.65,29.5,30.0,30.299999,29.450001,29.1,27.049999,27.5,27.25,27.700001,26.75,26.75,26.5,26.5,26.65,27.4,27.700001,27.35,27.15,27.6,28.049999,28.299999,28.450001,28.15,28.950001,29.299999,29.6,29.200001,29.299999,29.299999,29.6,29.799999,29.950001,30.15,29.950001,29.950001,29.6,28.950001,29.5,29.35,29.700001,29.799999,30.65,31.549999,31.4,31.1,31.450001,31.799999,33.400002,32.700001,32.400002,31.85,31.299999,32.200001,32.150002,32.049999,32.299999,32.700001,32.549999,32.900002,33.650002,32.599998,32.200001,32.25,31.950001,32.049999,32.25,32.099998,32.150002,32.049999,31.85,31.75,31.5,31.15,30.4,30.65,30.25,30.15,30.049999,29.9,29.799999,29.65,29.950001,29.9,29.65,29.25,29.65,30.1,29.25,29.049999,29.6,29.65,29.15,28.85,28.75,28.15,27.65,27.75,27.75,27.85,28.049999,28.15,28.200001,28.25,28.200001,30.0,29.35,31.4,31.0,30.549999,30.200001,30.299999,30.049999,30.25,30.1,30.700001,30.15,30.35,30.25,30.049999,29.85,30.25,30.450001,30.200001,30.0,30.200001,30.9,30.950001,30.950001,30.950001,30.299999,30.15,30.25,30.700001,34.049999,32.599998,32.5,35.900002,43.049999,38.75,37.700001,37.099998,36.700001,35.299999,36.200001,36.049999,35.5,36.299999,39.349998,39.299999,38.5,38.5,37.599998,37.25,36.799999,36.849998,36.049999,34.849998,36.5,36.049999,36.5,35.099998,33.450001,33.549999,34.049999,34.349998,34 ...

# %%
df['EMA_9'] = df['Close'].ewm(9).mean().shift()
df['SMA_5'] = df['Close'].rolling(5).mean().shift()
df['SMA_10'] = df['Close'].rolling(10).mean().shift()
df['SMA_15'] = df['Close'].rolling(15).mean().shift()
df['SMA_30'] = df['Close'].rolling(30).mean().shift()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df.Date, y=df.EMA_9, name='EMA 9'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_5, name='SMA 5'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_10, name='SMA 10'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_15, name='SMA 15'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_30, name='SMA 30'))
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close', opacity=0.2))
fig.show()
# Out:
# <div>                            <div id="b5281e00-f227-4c89-adbd-8aaf5fa4d1ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5281e00-f227-4c89-adbd-8aaf5fa4d1ef")) {                    Plotly.newPlot(                        "b5281e00-f227-4c89-adbd-8aaf5fa4d1ef",                        [{"name":"EMA 9","x":["2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:0 ...

# %%
def relative_strength_idx(df, n=14):
    close = df['Close']
    delta = close.diff()
    delta = delta[1:]
    pricesUp = delta.copy()
    pricesDown = delta.copy()
    pricesUp[pricesUp < 0] = 0
    pricesDown[pricesDown > 0] = 0    
    rollUp = pricesUp.rolling(n).mean()
    rollDown = pricesDown.abs().rolling(n).mean()
    rs = rollUp / rollDown
    rsi = 100.0 - (100.0 / (1.0 + rs))
    return rsi

df['RSI'] = relative_strength_idx(df).fillna(0)

fig = go.Figure(go.Scatter(x=df.Date, y=df.RSI, name='RSI'))
fig.show()
# Out:
# <div>                            <div id="6e319c33-f0e1-46a1-8dea-b76948681689" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e319c33-f0e1-46a1-8dea-b76948681689")) {                    Plotly.newPlot(                        "6e319c33-f0e1-46a1-8dea-b76948681689",                        [{"name":"RSI","x":["2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00: ...

# %%
EMA_12 = pd.Series(df['Close'].ewm(span=12, min_periods=12).mean())
EMA_26 = pd.Series(df['Close'].ewm(span=26, min_periods=26).mean())
df['MACD'] = pd.Series(EMA_12 - EMA_26)
df['MACD_signal'] = pd.Series(df.MACD.ewm(span=9, min_periods=9).mean())

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_12, name='EMA 12'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_26, name='EMA 26'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD'], name='MACD'), row=2, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD_signal'], name='Signal line'), row=2, col=1)
fig.show()
# Out:
# <div>                            <div id="c6f741e7-f41b-4d8f-b4f7-e7987ea98377" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6f741e7-f41b-4d8f-b4f7-e7987ea98377")) {                    Plotly.newPlot(                        "c6f741e7-f41b-4d8f-b4f7-e7987ea98377",                        [{"name":"Close","x":["2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:0 ...

# %%
df['Close'] = df['Close'].shift(-1)

# %%
df = df.iloc[33:] # Because of moving averag    If the version of a package is being increased, please remember to return the build/number back to 0.
df = df[:-1]      # Because of shifting close price

df.index = range(len(df))

# %%
test_size  = 0.15
valid_size = 0.15
   
test_split_idx  = int(df.shape[0] * (1-test_size))
valid_split_idx = int(df.shape[0] * (1-(valid_size+test_size)))

train_df  = df.loc[:valid_split_idx].copy()
valid_df  = df.loc[valid_split_idx+1:test_split_idx].copy()
test_df   = df.loc[test_split_idx+1:].copy()

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_df.Date, y=train_df.Close, name='Training'))
fig.add_trace(go.Scatter(x=valid_df.Date, y=valid_df.Close, name='Validation'))
fig.add_trace(go.Scatter(x=test_df.Date,  y=test_df.Close,  name='Test'))
fig.show()
# Out:
# <div>                            <div id="097706b5-281f-4985-94cd-c5c634b112b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("097706b5-281f-4985-94cd-c5c634b112b0")) {                    Plotly.newPlot(                        "097706b5-281f-4985-94cd-c5c634b112b0",                        [{"name":"Training","x":["2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-19T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","2020-10-22T00:00:00","2020-10-23T0 ...

# %%
drop_cols = ['Date', 'Volume', 'Open', 'Low', 'High']

train_df = train_df.drop(columns=drop_cols)
valid_df = valid_df.drop(columns=drop_cols)
test_df  = test_df.drop(columns=drop_cols)

# %%
y_train = train_df['Close'].copy()
X_train = train_df.drop(columns=['Close'])

y_valid = valid_df['Close'].copy()
X_valid = valid_df.drop(columns=['Close'])

y_test  = test_df['Close'].copy()
X_test  = test_df.drop(columns=['Close'])

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EMA_9        586 non-null    float64
#  1   SMA_5        586 non-null    float64
#  2   SMA_10       586 non-null    float64
#  3   SMA_15       586 non-null    float64
#  4   SMA_30       586 non-null    float64
#  5   RSI          586 non-null    float64
#  6   MACD         586 non-null    float64
#  7   MACD_signal  586 non-null    float64
# dtypes: float64(8)
# memory usage: 36.8 KB

# %%
# %%time

parameters = {
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [8, 10, 12, 15],
    'gamma': [0.001, 0.005, 0.01, 0.02],
    'random_state': [42],
}

eval_set = [(X_train, y_train), (X_valid, y_valid)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror')
clf = GridSearchCV(model, parameters)

clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best validation score = {clf.best_score_}')
# Out:
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:50:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:51:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:52:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# ...
#
# [16:53:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:53:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# [16:54:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set" } are not used.
#
# Best params: {'gamma': 0.001, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 100, 'random_state': 42}
# Best validation score = 0.34330223332804033
# CPU times: user 52min 16s, sys: 1min, total: 53min 16s
# Wall time: 3min 25s

# %%
# %%time

parameters = {
    'n_estimators': 800,
    'learning_rate': 0.01,
    'max_depth': 64,
    'gamma': 0.001,
    'random_state': 42
}

model = xgb.XGBRegressor(**clf.best_params_, objective='reg:squarederror')
# model = xgb.XGBRegressor(**parameters, objective='reg:squarederror')
# Out:
# CPU times: user 21 µs, sys: 0 ns, total: 21 µs
# Wall time: 24.8 µs

# %%
model.fit(X_train, y_train, eval_set=eval_set, verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.001, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
y_pred = model.predict(X_test)
print(f'y_true = {np.array(y_test)[:5]}')
print(f'y_pred = {y_pred[:5]}')
# Out:
# y_true = [76.75     76.150002 75.449997 75.599998 73.      ]
# y_pred = [34.459248 34.459248 34.459248 34.152924 34.459248]

# %%
predicted_prices = df.loc[test_split_idx+1:].copy()
predicted_prices['Close'] = y_pred

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close,
                         name='Truth',
                         marker_color='LightSkyBlue'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=predicted_prices.Close,
                         name='Prediction',
                         marker_color='MediumPurple'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_test,
                         name='Truth',
                         marker_color='LightSkyBlue',
                         showlegend=False), row=2, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_pred,
                         name='Prediction',
                         marker_color='MediumPurple',
                         showlegend=False), row=2, col=1)

fig.show()
# Out:
# <div>                            <div id="6ca344a7-4e67-4300-8ff2-92c349df8c28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ca344a7-4e67-4300-8ff2-92c349df8c28")) {                    Plotly.newPlot(                        "6ca344a7-4e67-4300-8ff2-92c349df8c28",                        [{"marker":{"color":"LightSkyBlue"},"name":"Truth","x":["2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-03T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:00:00","2020-08-17T00:00:00","2020-08-18T00:00:00","2020-08-19T00:00:00","2020-08-20T00:00:00","2020-08-21T00:00:00","2020-08-24T00:00:00","2020-08-25T00:00:00","2020-08-26T00:00:00","2020-08-27T00:00:00","2020-08-28T00:00:00","2020-08-31T00:00:00","2020-09-01T00:00:00","2020-09-02T00:00:00","2020-09-03T00:00:00","2020-09-04T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-19T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","202 ...
