# %% [markdown]
# ### This is for the reliance_data_set_large.csv

# %%
import os
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# Chart drawing
import plotly as py
import plotly.io as pio    
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# Mute sklearn warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=DeprecationWarning)

# Show charts when running kernel
init_notebook_mode(connected=True)

layout=go.Layout(paper_bgcolor='rgba(0,0,0,0)', plot_bgcolor='rgba(250,250,250,0.8)')
fig = go.Figure(layout=layout)
templated_fig = pio.to_templated(fig)
pio.templates['my_template'] = templated_fig.layout.template
pio.templates.default = 'my_template'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("../data/reliance_data_large.csv")

df['Date'] = pd.to_datetime(df['Date'])
df = df[(df['Date'].dt.year >= 2010)].copy()
df.index = range(len(df))
df.rename(columns={"Open Price":"Open","High Price":"High","Low Price":"Low","Close Price":"Close","Total Traded Quantity":"Volume"},inplace=True)
cols = ["Symbol","Series","Prev Close","Last Price","Average Price","Turnover","No. of Trades", "Deliverable Qty",'% Dly Qt to Traded Qty']
df.drop(columns=cols,inplace=True)   
df.head()
# Out:
# /tmp/ipykernel_48630/1727945649.py:3: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#         Date     Open    High      Low    Close   Volume
# 0 2016-01-01  1009.80  1018.9  1008.20  1015.35  1238135
# 1 2016-01-04  1005.00  1013.8   986.70   995.30  6896571
# 2 2016-01-05  1000.30  1010.0   997.00  1005.15  3416459
# 3 2016-01-06  1007.60  1038.4  1000.40  1032.20  6116855
# 4 2016-01-07  1021.05  1028.0  1008.05  1013.25  4512219

# %%
fig = make_subplots(rows=2, cols=1)

fig.add_trace(go.Ohlc(x=df.Date,
                      open=df.Open,
                      high=df.High,
                      low=df.Low,
                      close=df.Close,
                      name='Price'), row=1, col=1)

fig.add_trace(go.Scatter(x=df.Date, y=df.Volume, name='Volume'), row=2, col=1)

fig.update(layout_xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <div>                            <div id="daa1e25a-75d8-40f5-b7cb-02fa5a86a766" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daa1e25a-75d8-40f5-b7cb-02fa5a86a766")) {                    Plotly.newPlot(                        "daa1e25a-75d8-40f5-b7cb-02fa5a86a766",                        [{"close":[1015.35,995.3,1005.15,1032.2,1013.25,1025.75,1051.6,1045.45,1076.85,1061.65,1073.3,1016.85,1043.6,1004.55,984.2,1004.15,1003.95,999.35,1016.9,1035.4,1030.3,1001.15,981.4,973.05,970.9,961.05,957.5,962.65,924.55,906.55,946.75,930.55,952.6,940.1,944.35,962.3,949.65,952.65,944.1,950.35,966.65,981.3,1001.5,1012.85,1006.4,1027.0,1041.7,1011.75,1014.5,1019.75,1020.5,1021.75,1016.0,1027.2,1037.3,1047.85,1029.2,1020.4,1036.25,1047.05,1045.2,1034.45,1035.05,1026.95,1033.75,1037.25,1036.35,1040.3,1047.4,1066.05,1064.75,1037.3,1041.15,1038.95,1016.9,1016.95,1019.4,996.7,982.7,986.95,975.8,978.1,975.25,968.95,983.1,982.55,975.4,992.8,978.15,975.95,969.15,970.55,951.2,934.2,930.0,940.45,951.2,946.85,974.7,968.7,957.85,953.6,956.25,959.65,954.8,955.05,954.1,971.15,976.7,981.1,976.25,984.6,976.3,974.9,990.2,987.1,980.5,980.45,951.45,955.65,957.8,966.9,969.15,973.45,986.7,993.1,987.9,978.4,992.5,1003.4,1008.75,1004.9,1012.2,1006.25,1017.8,1023.0,1006.35,1014.85,1022.75,1024.05,1013.1,1026.35,1014.9,1009.5,1012.8,993.95,993.0,1016.25,1029.25,1030.7,1003.65,1014.1,1035.8,1024.9,1013.3,
# %%
df['EMA_9'] = df['Close'].ewm(9).mean().shift()
df['SMA_5'] = df['Close'].rolling(5).mean().shift()
df['SMA_10'] = df['Close'].rolling(10).mean().shift()
df['SMA_15'] = df['Close'].rolling(15).mean().shift()
df['SMA_30'] = df['Close'].rolling(30).mean().shift()

fig = go.Figure()
fig.add_trace(go.Scatter(x=df.Date, y=df.EMA_9, name='EMA 9'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_5, name='SMA 5'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_10, name='SMA 10'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_15, name='SMA 15'))
fig.add_trace(go.Scatter(x=df.Date, y=df.SMA_30, name='SMA 30'))
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close', opacity=0.2))
fig.show()
# Out:
# <div>                            <div id="be265fa2-1191-43e9-9f9d-a3076ed705e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be265fa2-1191-43e9-9f9d-a3076ed705e1")) {                    Plotly.newPlot(                        "be265fa2-1191-43e9-9f9d-a3076ed705e1",                        [{"name":"EMA 9","x":["2016-01-01T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-08T00:00:00","2016-02-09T00:00:00","2016-02-10T00:00:00","2016-02-11T00:00:00","2016-02-12T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-18T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-02T00:00:00","2016-05-03T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08-16T00:00:00","2016-08-17T00:00:00","2016-08-18T00:00:00","2016-08-19T00:0 ...

# %%
def relative_strength_idx(df, n=14):
    close = df['Close']
    delta = close.diff()
    delta = delta[1:]
    pricesUp = delta.copy()
    pricesDown = delta.copy()
    pricesUp[pricesUp < 0] = 0
    pricesDown[pricesDown > 0] = 0    
    rollUp = pricesUp.rolling(n).mean()
    rollDown = pricesDown.abs().rolling(n).mean()
    rs = rollUp / rollDown
    rsi = 100.0 - (100.0 / (1.0 + rs))
    return rsi

df['RSI'] = relative_strength_idx(df).fillna(0)

fig = go.Figure(go.Scatter(x=df.Date, y=df.RSI, name='RSI'))
fig.show()
# Out:
# <div>                            <div id="b20c3e2b-1019-4d4a-b4e3-196d5f087090" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b20c3e2b-1019-4d4a-b4e3-196d5f087090")) {                    Plotly.newPlot(                        "b20c3e2b-1019-4d4a-b4e3-196d5f087090",                        [{"name":"RSI","x":["2016-01-01T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-08T00:00:00","2016-02-09T00:00:00","2016-02-10T00:00:00","2016-02-11T00:00:00","2016-02-12T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-18T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-02T00:00:00","2016-05-03T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08-16T00:00:00","2016-08-17T00:00:00","2016-08-18T00:00:00","2016-08-19T00:00: ...

# %%
EMA_12 = pd.Series(df['Close'].ewm(span=12, min_periods=12).mean())
EMA_26 = pd.Series(df['Close'].ewm(span=26, min_periods=26).mean())
df['MACD'] = pd.Series(EMA_12 - EMA_26)
df['MACD_signal'] = pd.Series(df.MACD.ewm(span=9, min_periods=9).mean())

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close, name='Close'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_12, name='EMA 12'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=EMA_26, name='EMA 26'), row=1, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD'], name='MACD'), row=2, col=1)
fig.add_trace(go.Scatter(x=df.Date, y=df['MACD_signal'], name='Signal line'), row=2, col=1)
fig.show()
# Out:
# <div>                            <div id="b7539b89-ce2c-4a24-be1f-4bd997026db7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7539b89-ce2c-4a24-be1f-4bd997026db7")) {                    Plotly.newPlot(                        "b7539b89-ce2c-4a24-be1f-4bd997026db7",                        [{"name":"Close","x":["2016-01-01T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-08T00:00:00","2016-02-09T00:00:00","2016-02-10T00:00:00","2016-02-11T00:00:00","2016-02-12T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-18T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-02T00:00:00","2016-05-03T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08-16T00:00:00","2016-08-17T00:00:00","2016-08-18T00:00:00","2016-08-19T00:0 ...

# %%
df['Close'] = df['Close'].shift(-1)

# %%
df = df.iloc[33:] # Because of moving averag    If the version of a package is being increased, please remember to return the build/number back to 0.
df = df[:-1]      # Because of shifting close price

df.index = range(len(df))

# %%
test_size  = 0.15
valid_size = 0.15
   
test_split_idx  = int(df.shape[0] * (1-test_size))
valid_split_idx = int(df.shape[0] * (1-(valid_size+test_size)))

train_df  = df.loc[:valid_split_idx].copy()
valid_df  = df.loc[valid_split_idx+1:test_split_idx].copy()
test_df   = df.loc[test_split_idx+1:].copy()

fig = go.Figure()
fig.add_trace(go.Scatter(x=train_df.Date, y=train_df.Close, name='Training'))
fig.add_trace(go.Scatter(x=valid_df.Date, y=valid_df.Close, name='Validation'))
fig.add_trace(go.Scatter(x=test_df.Date,  y=test_df.Close,  name='Test'))
fig.show()
# Out:
# <div>                            <div id="1137b736-0ab1-409a-8125-8c3ba7be5808" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1137b736-0ab1-409a-8125-8c3ba7be5808")) {                    Plotly.newPlot(                        "1137b736-0ab1-409a-8125-8c3ba7be5808",                        [{"name":"Training","x":["2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-18T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-05-02T00:00:00","2016-05-03T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-07T00:00:00","2016-06-08T00:00:00","2016-06-09T00:00:00","2016-06-10T00:00:00","2016-06-13T00:00:00","2016-06-14T00:00:00","2016-06-15T00:00:00","2016-06-16T00:00:00","2016-06-17T00:00:00","2016-06-20T00:00:00","2016-06-21T00:00:00","2016-06-22T00:00:00","2016-06-23T00:00:00","2016-06-24T00:00:00","2016-06-27T00:00:00","2016-06-28T00:00:00","2016-06-29T00:00:00","2016-06-30T00:00:00","2016-07-01T00:00:00","2016-07-04T00:00:00","2016-07-05T00:00:00","2016-07-07T00:00:00","2016-07-08T00:00:00","2016-07-11T00:00:00","2016-07-12T00:00:00","2016-07-13T00:00:00","2016-07-14T00:00:00","2016-07-15T00:00:00","2016-07-18T00:00:00","2016-07-19T00:00:00","2016-07-20T00:00:00","2016-07-21T00:00:00","2016-07-22T00:00:00","2016-07-25T00:00:00","2016-07-26T00:00:00","2016-07-27T00:00:00","2016-07-28T00:00:00","2016-07-29T00:00:00","2016-08-01T00:00:00","2016-08-02T00:00:00","2016-08-03T00:00:00","2016-08-04T00:00:00","2016-08-05T00:00:00","2016-08-08T00:00:00","2016-08-09T00:00:00","2016-08-10T00:00:00","2016-08-11T00:00:00","2016-08-12T00:00:00","2016-08-16T00:00:00","2016-08-17T00:00:00","2016-08-18T00:00:00","2016-08-19T00:00:00","2016-08-22T00:00:00","2016-08-23T00:00:00","2016-08-24T00:00:00","2016-08-25T00:00:00","2016-08-26T00:00:00","2016-08-29T00:00:00","2016-08-30T00:00:00","2016-08-31T00:00:00","2016-09-01T00:00:00","2016-09-02T00:00:00","2016-09-06T00:00:00","2016-09-07T00:00:00","2016-09-08T00:00:00","2016-09-09T00:00:00","2016-09-12T00:00:00","2016-09-14T00:00:00","2016-09-15T00:00:00","2016-09-16T00:00:00","2016-09-19T00:00:00","2016-09-20T00:00:00","2016-09-21T00:00:00","2016-09-22T00:00:00","2016-09-23T00:00:00","2016-09-26T00:00:00","2016-09-27T00:00:00","2016-09-28T00:00:00","2016-09-29T00:00:00","2016-09-30T00:00:00","2016-10-03T00:00:00","2016-10-04T00:00:00","2016-10-05T00:00:00","2016-10-06T00:00:00","2016-10-07T0 ...

# %%
drop_cols = ['Date', 'Volume', 'Open', 'Low', 'High']

train_df = train_df.drop(columns=drop_cols)
valid_df = valid_df.drop(columns=drop_cols)
test_df  = test_df.drop(columns=drop_cols)

# %%
y_train = train_df['Close'].copy()
X_train = train_df.drop(columns=['Close'])

y_valid = valid_df['Close'].copy()
X_valid = valid_df.drop(columns=['Close'])

y_test  = test_df['Close'].copy()
X_test  = test_df.drop(columns=['Close'])

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EMA_9        903 non-null    float64
#  1   SMA_5        903 non-null    float64
#  2   SMA_10       903 non-null    float64
#  3   SMA_15       903 non-null    float64
#  4   SMA_30       903 non-null    float64
#  5   RSI          903 non-null    float64
#  6   MACD         903 non-null    float64
#  7   MACD_signal  903 non-null    float64
# dtypes: float64(8)
# memory usage: 56.6 KB

# %%
# %%time

parameters = {
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [8, 10, 12, 15],
    'gamma': [0.001, 0.005, 0.01, 0.02],
    'random_state': [42]
}

eval_set = [(X_train, y_train), (X_valid, y_valid)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
clf = GridSearchCV(model, parameters)

clf.fit(X_train, y_train)

print(f'Best params: {clf.best_params_}')
print(f'Best validation score = {clf.best_score_}')
# Out:
# [15:29:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:29:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:29:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:29:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:29:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:29:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:30:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:30:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:30:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:30:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:31:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:31:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:31:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:31:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:32:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:32:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:33:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:33:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:34:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:34:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:35:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:35:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:35:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:35:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:36:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:36:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:36:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:36:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:36:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:37:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:37:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:37:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:38:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:38:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:38:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:39:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:39:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:39:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:40:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:40:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:41:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:41:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:42:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:42:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:42:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:42:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:43:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:43:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:43:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:43:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:44:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:44:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:45:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:45:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:45:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:46:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:46:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:46:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:46:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:47:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:47:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:47:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:47:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:47:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:47:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:47:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:48:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:48:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:48:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:48:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:49:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:49:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:49:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:50:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:50:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:50:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:51:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:51:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:51:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:52:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:52:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:52:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:52:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:52:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:52:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:53:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:53:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:53:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:53:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:53:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:54:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:54:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:54:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:54:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:55:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:56:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:56:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:56:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:57:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:57:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:57:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:57:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:57:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:57:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:58:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:58:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:58:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:58:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:58:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:59:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:59:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:59:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [15:59:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:00:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:00:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:01:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:01:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:01:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:02:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:02:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:02:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:02:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:02:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:03:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:03:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:03:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:03:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:03:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:04:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:04:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:05:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:05:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:05:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:06:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:52] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:56] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:07:58] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:08] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:09] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:10] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:11] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:12] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:13] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:14] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:16] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:17] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:18] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:19] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:20] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:21] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:22] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:23] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:24] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:25] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:27] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:28] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:29] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:30] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:32] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:33] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:34] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:35] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:36] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:39] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:40] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:41] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:42] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:43] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:44] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:45] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:46] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:47] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:48] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:49] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:50] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:51] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:53] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:54] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:55] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:57] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:08:59] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:00] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:01] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:02] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:03] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:04] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:05] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:06] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.
#
# [16:09:07] WARNING: ../src/learner.cc:767:
# Parameters: { "eval_set", "verbose" } are not used.

# %%
# %%time

model = xgb.XGBRegressor(**clf.best_params_, objective='reg:squarederror')

# %%
model.fit(X_train, y_train, eval_set=eval_set, verbose=False)

# %%
plot_importance(model);

# %%
y_pred = model.predict(X_test)
print(f'y_true = {np.array(y_test)[:5]}')
print(f'y_pred = {y_pred[:5]}')

# %%
predicted_prices = df.loc[test_split_idx+1:].copy()
predicted_prices['Close'] = y_pred

fig = make_subplots(rows=2, cols=1)
fig.add_trace(go.Scatter(x=df.Date, y=df.Close,
                         name='Truth',
                         marker_color='LightSkyBlue'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=predicted_prices.Close,
                         name='Prediction',
                         marker_color='MediumPurple'), row=1, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_test,
                         name='Truth',
                         marker_color='LightSkyBlue',
                         showlegend=False), row=2, col=1)

fig.add_trace(go.Scatter(x=predicted_prices.Date,
                         y=y_pred,
                         name='Prediction',
                         marker_color='MediumPurple',
                         showlegend=False), row=2, col=1)

fig.show()

# %% [markdown]
# <!-- 1st MAy 2020 - 31st december 2022 -->
